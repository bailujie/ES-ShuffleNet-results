# %%
# -*- coding: utf-8 -*-
from __future__ import print_function
"""
Created on Tue Oct 23 14:03:51 2018

@author: xingshuli

"""

from keras import applications
from keras_applications.imagenet_utils import _obtain_input_shape
from keras.engine.topology import get_source_inputs
#from keras_flops import get_flops
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import Activation
from keras.layers import Dense
from keras.layers import BatchNormalization
from keras.layers import Concatenate
from keras.layers.convolutional import DepthwiseConv2D
#from keras_applications import DepthwiseConv2D
from keras.layers import Lambda
from keras.layers import MaxPooling2D
from keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D
from keras.models import Model
from keras import backend as K
import keras.layers  as KL
import numpy as np

def channel_split(x, name = ''):
    in_channels = x.shape.as_list()[-1]
    ip = in_channels // 2
    c_hat = Lambda(lambda z: z[:, :, :, 0:ip])(x)
    c = Lambda(lambda z: z[:, :, :, ip:])(x)
    
    return c_hat, c


def channel_shuffle(x):
    height, width, channels = x.shape.as_list()[1:]
    channels_per_split = channels // 2
    
    x = K.reshape(x, [-1, height, width, 2, channels_per_split])
    x = K.permute_dimensions(x, (0,1,2,4,3))
    x = K.reshape(x, [-1, height, width, channels])
    
    return x

def _shuffle_unit(inputs, out_channels, strides = 2, stage = 1, block = 1):
    
    bn_axis = -1
    prefix = 'stage%d/block%d' %(stage, block)
    
    branch_channels = out_channels // 2
    
    if strides == 2:
        x_1 = DepthwiseConv2D(kernel_size = 3, strides = 2, padding = 'same', 
                              use_bias = False, name = '%s/3x3dwconv_1' % prefix)(inputs)
        x_1 = BatchNormalization(axis = bn_axis, name = '%s/bn_3x3dwconv_1' % prefix)(x_1)
        x_1 = Conv2D(filters = branch_channels, kernel_size = 1, strides = 1, padding = 'same', 
                     use_bias = False, name = '%s/1x1conv_1' % prefix)(x_1)
        x_1 = BatchNormalization(axis = bn_axis, name = '%s/bn_1x1conv_1' % prefix)(x_1)
        x_1 = Activation('relu')(x_1)
        
        x_2 = Conv2D(filters = branch_channels, kernel_size = 1, strides = 1, padding = 'same', 
                     use_bias = False, name = '%s/1x1conv_2' % prefix)(inputs)
        x_2 = BatchNormalization(axis = bn_axis, name = '%s/bn_1x1conv_2' % prefix)(x_2)
        x_2 = Activation('relu')(x_2)
        x_2 = DepthwiseConv2D(kernel_size = 3, strides = 2, padding = 'same', 
                              use_bias = False, name = '%s/3x3dwconv_2' % prefix)(x_2)
        x_2 = BatchNormalization(axis = bn_axis, name = '%s/bn_3x3dwconv_2' % prefix)(x_2)
        x_2 = Conv2D(filters = branch_channels, kernel_size = 1, strides = 1, padding = 'same', 
                     use_bias = False, name = '%s/1x1conv_3' % prefix)(x_2)
        x_2 = BatchNormalization(axis = bn_axis, name = '%s/bn_1x1conv_3' % prefix)(x_2)
        x_2 = Activation('relu')(x_2)
        
        #x_1 = SGE(groups=16)(x_1)
        #x_2 = SGE(groups=16)(x_2)
        
        x = Concatenate(axis = bn_axis, name = '%s/concat' % prefix)([x_1, x_2])
        
    if strides == 1:
        c_hat, c = channel_split(inputs, name = '%s/split' % prefix)
        
        c = Conv2D(filters = branch_channels, kernel_size = 1, strides = 1, padding = 'same', 
                   use_bias = False, name = '%s/1x1conv_4' % prefix)(c)
        c = BatchNormalization(axis = bn_axis, name = '%s/bn_1x1conv_4' % prefix)(c)
        c = Activation('relu')(c)
        c = DepthwiseConv2D(kernel_size = 3, strides = 1, padding = 'same', 
                            use_bias = False, name = '%s/3x3dwconv_3' % prefix)(c)
        c = BatchNormalization(axis = bn_axis, name = '%s/bn_3x3dwconv_3' % prefix)(c)
        c = Conv2D(filters = branch_channels, kernel_size = 1, strides = 1, padding = 'same', 
                   use_bias = False, name = '%s/1x1conv_5' % prefix)(c)
        c = BatchNormalization(axis = bn_axis, name = '%s/bn_1x1conv_5' % prefix)(c)
        c = Activation('relu')(c)
        
        
        x = Concatenate(axis = bn_axis, name = '%s/concat' % prefix)([c_hat, c])
        
    x = Lambda(channel_shuffle, name = '%s/channel_shuffle' % prefix)(x)
    
    return x

def v2_block(x, channel_map, repeat = 1, stage = 1):
    x = _shuffle_unit(x, out_channels = channel_map[stage - 1], strides = 2, 
                      stage = stage, block = 1)
    
    for i in range(1, repeat + 1):
        x = _shuffle_unit(x, out_channels = channel_map[stage - 1], strides = 1, 
                          stage = stage, block = (i + 1))
    
    return x


def ShuffleNet_V2(include_top = True, input_tensor = None, scale_factor = 1.0, pooling = 'avg', 
                  input_shape = (256, 256, 3), num_shuffle_units = [1, 2, 1], weights = None, 
                  classes = 6):
    if K.backend() != 'tensorflow':
        raise RuntimeError('Only TensorFlow backend is currently supported')
    
    input_shape = _obtain_input_shape(input_shape, 
                                      default_size = 224, 
                                      min_size = 28, 
                                      data_format = K.image_data_format(), 
                                      require_flatten = include_top, 
                                      weights = weights)
    
    out_dim_stage_two = {0.5: 48, 1: 116, 1.5: 176, 2: 244}
    
    if pooling not in ['max', 'avg']:
        raise ValueError('Invalid value for pooling')
    
    if not (float(scale_factor) * 4).is_integer():
        raise ValueError('Invalid value for scale_factor. Should be x over 4')
    
    exp = np.insert(np.arange(len(num_shuffle_units), dtype = np.float32), 0, 0)
    out_channels_in_stage = 2 ** exp
    out_channels_in_stage *= out_dim_stage_two[scale_factor]
    out_channels_in_stage[0] = 24
    out_channels_in_stage = out_channels_in_stage.astype(int)
    
    if input_tensor is None:
        img_input = Input(shape = input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(shape = input_shape, tensor = input_tensor)
        else:
            img_input = input_tensor
            
    
    x = Conv2D(filters = out_channels_in_stage[0], kernel_size = 3, strides = 2, 
               padding = 'same', use_bias = False, activation = 'relu', name = 'conv1')(img_input)
    y = se_block(x)
    #y = SGE(groups=x)
    x = KL.add([x,y])
    x = MaxPooling2D(pool_size = 3, strides = 2, padding = 'same', name = 'MaxPool1')(x)
    #y = SGE(groups=groups)(img_input)
    #x = KL.add([x,y])
    
    #construct stage2 to 4
    for stage in range(len(num_shuffle_units)):
        repeat = num_shuffle_units[stage]
        x = v2_block(x, channel_map = out_channels_in_stage, repeat = repeat, stage = stage + 2)
        
        
    #construct final layers
    if scale_factor == 2:
        x = Conv2D(filters = 2048, kernel_size = 1, strides = 1, padding = 'same', 
                   use_bias = False, activation = 'relu', name = 'conv5')(x)
    else:
        x = Conv2D(filters = 1024, kernel_size = 1, strides = 1, padding = 'same', 
                   use_bias = False, activation = 'relu', name = 'conv5')(x)
    
    if pooling == 'avg':
        x = GlobalAveragePooling2D(name = 'global_average_pool')(x)
        #x = SGE(groups=16)(x)
    elif pooling == 'max':
        x = GlobalMaxPooling2D(name = 'global_max_pool')(x)
        
        #y = SGE(groups=16)(x)
        #x = KL.add([x,y])
    
    if include_top:
        x = Dense(classes, name = 'fc')(x)
        x = Activation('softmax')(x)
       
        
    if input_tensor is not None:
        inputs = get_source_inputs(input_tensor)
    else:  
        inputs = img_input
    
    #construct model function
    model = Model(inputs = inputs, outputs = x, name = 'ShuffleNet_V2')
    
    return model



if __name__ == '__main__':
    
    
    model = ShuffleNet_V2(input_shape=[256,256,3],  # 输入图像的shape
                       classes = 6) # 图像分类类别
   
    model.summary()  # 查看网络结构
 


    model_layers = [ layer.name for layer in model.layers]
    print('layer name : ',model_layers)

    keras.utils.plot_model(model,"my_CNN_model1230.png")

#print('flops:', get_flops(model, batch_size=1))
# Out:
# WARNING:tensorflow:From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From D:\anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Model: "ShuffleNet_V2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 128, 128, 24) 648         input_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 24)           0           conv1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 24)     0           global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 1, 1, 6)      150         reshape_1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 1, 1, 6)      0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 1, 1, 24)     168         re_lu_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1, 1, 24)     0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 128, 128, 24) 0           conv1[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 128, 128, 24) 0           multiply_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 128, 128, 24) 0           conv1[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# MaxPool1 (MaxPooling2D)         (None, 64, 64, 24)   0           add_1[0][0]
# __________________________________________________________________________________________________
# stage2/block1/1x1conv_2 (Conv2D (None, 64, 64, 58)   1392        MaxPool1[0][0]
# __________________________________________________________________________________________________
# stage2/block1/bn_1x1conv_2 (Bat (None, 64, 64, 58)   232         stage2/block1/1x1conv_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 58)   0           stage2/block1/bn_1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage2/block1/3x3dwconv_1 (Dept (None, 32, 32, 24)   216         MaxPool1[0][0]
# __________________________________________________________________________________________________
# stage2/block1/3x3dwconv_2 (Dept (None, 32, 32, 58)   522         activation_3[0][0]
# __________________________________________________________________________________________________
# stage2/block1/bn_3x3dwconv_1 (B (None, 32, 32, 24)   96          stage2/block1/3x3dwconv_1[0][0]
# __________________________________________________________________________________________________
# stage2/block1/bn_3x3dwconv_2 (B (None, 32, 32, 58)   232         stage2/block1/3x3dwconv_2[0][0]
# __________________________________________________________________________________________________
# stage2/block1/1x1conv_1 (Conv2D (None, 32, 32, 58)   1392        stage2/block1/bn_3x3dwconv_1[0][0
# __________________________________________________________________________________________________
# stage2/block1/1x1conv_3 (Conv2D (None, 32, 32, 58)   3364        stage2/block1/bn_3x3dwconv_2[0][0
# __________________________________________________________________________________________________
# stage2/block1/bn_1x1conv_1 (Bat (None, 32, 32, 58)   232         stage2/block1/1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage2/block1/bn_1x1conv_3 (Bat (None, 32, 32, 58)   232         stage2/block1/1x1conv_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 58)   0           stage2/block1/bn_1x1conv_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 58)   0           stage2/block1/bn_1x1conv_3[0][0]
# __________________________________________________________________________________________________
# stage2/block1/concat (Concatena (None, 32, 32, 116)  0           activation_2[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# stage2/block1/channel_shuffle ( (None, 32, 32, 116)  0           stage2/block1/concat[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 32, 32, 58)   0           stage2/block1/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage2/block2/1x1conv_4 (Conv2D (None, 32, 32, 58)   3364        lambda_3[0][0]
# __________________________________________________________________________________________________
# stage2/block2/bn_1x1conv_4 (Bat (None, 32, 32, 58)   232         stage2/block2/1x1conv_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 58)   0           stage2/block2/bn_1x1conv_4[0][0]
# __________________________________________________________________________________________________
# stage2/block2/3x3dwconv_3 (Dept (None, 32, 32, 58)   522         activation_5[0][0]
# __________________________________________________________________________________________________
# stage2/block2/bn_3x3dwconv_3 (B (None, 32, 32, 58)   232         stage2/block2/3x3dwconv_3[0][0]
# __________________________________________________________________________________________________
# stage2/block2/1x1conv_5 (Conv2D (None, 32, 32, 58)   3364        stage2/block2/bn_3x3dwconv_3[0][0
# __________________________________________________________________________________________________
# stage2/block2/bn_1x1conv_5 (Bat (None, 32, 32, 58)   232         stage2/block2/1x1conv_5[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 32, 32, 58)   0           stage2/block1/channel_shuffle[0][
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 58)   0           stage2/block2/bn_1x1conv_5[0][0]
# __________________________________________________________________________________________________
# stage2/block2/concat (Concatena (None, 32, 32, 116)  0           lambda_2[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# stage2/block2/channel_shuffle ( (None, 32, 32, 116)  0           stage2/block2/concat[0][0]
# __________________________________________________________________________________________________
# stage3/block1/1x1conv_2 (Conv2D (None, 32, 32, 116)  13456       stage2/block2/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage3/block1/bn_1x1conv_2 (Bat (None, 32, 32, 116)  464         stage3/block1/1x1conv_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 116)  0           stage3/block1/bn_1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage3/block1/3x3dwconv_1 (Dept (None, 16, 16, 116)  1044        stage2/block2/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage3/block1/3x3dwconv_2 (Dept (None, 16, 16, 116)  1044        activation_8[0][0]
# __________________________________________________________________________________________________
# stage3/block1/bn_3x3dwconv_1 (B (None, 16, 16, 116)  464         stage3/block1/3x3dwconv_1[0][0]
# __________________________________________________________________________________________________
# stage3/block1/bn_3x3dwconv_2 (B (None, 16, 16, 116)  464         stage3/block1/3x3dwconv_2[0][0]
# __________________________________________________________________________________________________
# stage3/block1/1x1conv_1 (Conv2D (None, 16, 16, 116)  13456       stage3/block1/bn_3x3dwconv_1[0][0
# __________________________________________________________________________________________________
# stage3/block1/1x1conv_3 (Conv2D (None, 16, 16, 116)  13456       stage3/block1/bn_3x3dwconv_2[0][0
# __________________________________________________________________________________________________
# stage3/block1/bn_1x1conv_1 (Bat (None, 16, 16, 116)  464         stage3/block1/1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage3/block1/bn_1x1conv_3 (Bat (None, 16, 16, 116)  464         stage3/block1/1x1conv_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 116)  0           stage3/block1/bn_1x1conv_1[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 116)  0           stage3/block1/bn_1x1conv_3[0][0]
# __________________________________________________________________________________________________
# stage3/block1/concat (Concatena (None, 16, 16, 232)  0           activation_7[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# stage3/block1/channel_shuffle ( (None, 16, 16, 232)  0           stage3/block1/concat[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 16, 16, 116)  0           stage3/block1/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage3/block2/1x1conv_4 (Conv2D (None, 16, 16, 116)  13456       lambda_5[0][0]
# __________________________________________________________________________________________________
# stage3/block2/bn_1x1conv_4 (Bat (None, 16, 16, 116)  464         stage3/block2/1x1conv_4[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16, 16, 116)  0           stage3/block2/bn_1x1conv_4[0][0]
# __________________________________________________________________________________________________
# stage3/block2/3x3dwconv_3 (Dept (None, 16, 16, 116)  1044        activation_10[0][0]
# __________________________________________________________________________________________________
# stage3/block2/bn_3x3dwconv_3 (B (None, 16, 16, 116)  464         stage3/block2/3x3dwconv_3[0][0]
# __________________________________________________________________________________________________
# stage3/block2/1x1conv_5 (Conv2D (None, 16, 16, 116)  13456       stage3/block2/bn_3x3dwconv_3[0][0
# __________________________________________________________________________________________________
# stage3/block2/bn_1x1conv_5 (Bat (None, 16, 16, 116)  464         stage3/block2/1x1conv_5[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 16, 16, 116)  0           stage3/block1/channel_shuffle[0][
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 116)  0           stage3/block2/bn_1x1conv_5[0][0]
# __________________________________________________________________________________________________
# stage3/block2/concat (Concatena (None, 16, 16, 232)  0           lambda_4[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# stage3/block2/channel_shuffle ( (None, 16, 16, 232)  0           stage3/block2/concat[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 16, 16, 116)  0           stage3/block2/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage3/block3/1x1conv_4 (Conv2D (None, 16, 16, 116)  13456       lambda_7[0][0]
# __________________________________________________________________________________________________
# stage3/block3/bn_1x1conv_4 (Bat (None, 16, 16, 116)  464         stage3/block3/1x1conv_4[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 116)  0           stage3/block3/bn_1x1conv_4[0][0]
# __________________________________________________________________________________________________
# stage3/block3/3x3dwconv_3 (Dept (None, 16, 16, 116)  1044        activation_12[0][0]
# __________________________________________________________________________________________________
# stage3/block3/bn_3x3dwconv_3 (B (None, 16, 16, 116)  464         stage3/block3/3x3dwconv_3[0][0]
# __________________________________________________________________________________________________
# stage3/block3/1x1conv_5 (Conv2D (None, 16, 16, 116)  13456       stage3/block3/bn_3x3dwconv_3[0][0
# __________________________________________________________________________________________________
# stage3/block3/bn_1x1conv_5 (Bat (None, 16, 16, 116)  464         stage3/block3/1x1conv_5[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 16, 16, 116)  0           stage3/block2/channel_shuffle[0][
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 116)  0           stage3/block3/bn_1x1conv_5[0][0]
# __________________________________________________________________________________________________
# stage3/block3/concat (Concatena (None, 16, 16, 232)  0           lambda_6[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# stage3/block3/channel_shuffle ( (None, 16, 16, 232)  0           stage3/block3/concat[0][0]
# __________________________________________________________________________________________________
# stage4/block1/1x1conv_2 (Conv2D (None, 16, 16, 232)  53824       stage3/block3/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage4/block1/bn_1x1conv_2 (Bat (None, 16, 16, 232)  928         stage4/block1/1x1conv_2[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 16, 16, 232)  0           stage4/block1/bn_1x1conv_2[0][0]
# __________________________________________________________________________________________________
# stage4/block1/3x3dwconv_1 (Dept (None, 8, 8, 232)    2088        stage3/block3/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage4/block1/3x3dwconv_2 (Dept (None, 8, 8, 232)    2088        activation_15[0][0]
# __________________________________________________________________________________________________
# stage4/block1/bn_3x3dwconv_1 (B (None, 8, 8, 232)    928         stage4/block1/3x3dwconv_1[0][0]
# __________________________________________________________________________________________________
# stage4/block1/bn_3x3dwconv_2 (B (None, 8, 8, 232)    928         stage4/block1/3x3dwconv_2[0][0]
# __________________________________________________________________________________________________
# stage4/block1/1x1conv_1 (Conv2D (None, 8, 8, 232)    53824       stage4/block1/bn_3x3dwconv_1[0][0
# __________________________________________________________________________________________________
# stage4/block1/1x1conv_3 (Conv2D (None, 8, 8, 232)    53824       stage4/block1/bn_3x3dwconv_2[0][0
# __________________________________________________________________________________________________
# stage4/block1/bn_1x1conv_1 (Bat (None, 8, 8, 232)    928         stage4/block1/1x1conv_1[0][0]
# __________________________________________________________________________________________________
# stage4/block1/bn_1x1conv_3 (Bat (None, 8, 8, 232)    928         stage4/block1/1x1conv_3[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 232)    0           stage4/block1/bn_1x1conv_1[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 8, 8, 232)    0           stage4/block1/bn_1x1conv_3[0][0]
# __________________________________________________________________________________________________
# stage4/block1/concat (Concatena (None, 8, 8, 464)    0           activation_14[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# stage4/block1/channel_shuffle ( (None, 8, 8, 464)    0           stage4/block1/concat[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 8, 8, 232)    0           stage4/block1/channel_shuffle[0][
# __________________________________________________________________________________________________
# stage4/block2/1x1conv_4 (Conv2D (None, 8, 8, 232)    53824       lambda_9[0][0]
# __________________________________________________________________________________________________
# stage4/block2/bn_1x1conv_4 (Bat (None, 8, 8, 232)    928         stage4/block2/1x1conv_4[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 232)    0           stage4/block2/bn_1x1conv_4[0][0]
# __________________________________________________________________________________________________
# stage4/block2/3x3dwconv_3 (Dept (None, 8, 8, 232)    2088        activation_17[0][0]
# __________________________________________________________________________________________________
# stage4/block2/bn_3x3dwconv_3 (B (None, 8, 8, 232)    928         stage4/block2/3x3dwconv_3[0][0]
# __________________________________________________________________________________________________
# stage4/block2/1x1conv_5 (Conv2D (None, 8, 8, 232)    53824       stage4/block2/bn_3x3dwconv_3[0][0
# __________________________________________________________________________________________________
# stage4/block2/bn_1x1conv_5 (Bat (None, 8, 8, 232)    928         stage4/block2/1x1conv_5[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 8, 8, 232)    0           stage4/block1/channel_shuffle[0][
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 8, 8, 232)    0           stage4/block2/bn_1x1conv_5[0][0]
# __________________________________________________________________________________________________
# stage4/block2/concat (Concatena (None, 8, 8, 464)    0           lambda_8[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# stage4/block2/channel_shuffle ( (None, 8, 8, 464)    0           stage4/block2/concat[0][0]
# __________________________________________________________________________________________________
# conv5 (Conv2D)                  (None, 8, 8, 1024)   475136      stage4/block2/channel_shuffle[0][
# __________________________________________________________________________________________________
# global_average_pool (GlobalAver (None, 1024)         0           conv5[0][0]
# __________________________________________________________________________________________________
# fc (Dense)                      (None, 6)            6150        global_average_pool[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 6)            0           fc[0][0]
# ==================================================================================================
# Total params: 884,388
# Trainable params: 877,264
# Non-trainable params: 7,124
# __________________________________________________________________________________________________
# layer name :  ['input_1', 'conv1', 'global_average_pooling2d_1', 'reshape_1', 'conv2d_1', 're_lu_1', 'conv2d_2', 'activation_1', 'multiply_1', 'lambda_1', 'add_1', 'MaxPool1', 'stage2/block1/1x1conv_2', 'stage2/block1/bn_1x1conv_2', 'activation_3', 'stage2/block1/3x3dwconv_1', 'stage2/block1/3x3dwconv_2', 'stage2/block1/bn_3x3dwconv_1', 'stage2/block1/bn_3x3dwconv_2', 'stage2/block1/1x1conv_1', 'stage2/block1/1x1conv_3', 'stage2/block1/bn_1x1conv_1', 'stage2/block1/bn_1x1conv_3', 'activation_2', 'activation_4', 'stage2/block1/concat', 'stage2/block1/channel_shuffle', 'lambda_3', 'stage2/block2/1x1conv_4', 'stage2/block2/bn_1x1conv_4', 'activation_5', 'stage2/block2/3x3dwconv_3', 'stage2/block2/bn_3x3dwconv_3', 'stage2/block2/1x1conv_5', 'stage2/block2/bn_1x1conv_5', 'lambda_2', 'activation_6', 'stage2/block2/concat', 'stage2/block2/channel_shuffle', 'stage3/block1/1x1conv_2', 'stage3/block1/bn_1x1conv_2', 'activation_8', 'stage3/block1/3x3dwconv_1', 'stage3/block1/3x3dwconv_2', 'stage3/block1/bn_3x3dwconv_1', 'stage3/block1/bn_3x3dwconv_2', 'stage3/block1/1x1conv_1', 'stage3/block1/1x1conv_3', 'stage3/block1/bn_1x1conv_1', 'stage3/block1/bn_1x1conv_3', 'activation_7', 'activation_9', 'stage3/block1/concat', 'stage3/block1/channel_shuffle', 'lambda_5', 'stage3/block2/1x1conv_4', 'stage3/block2/bn_1x1conv_4', 'activation_10', 'stage3/block2/3x3dwconv_3', 'stage3/block2/bn_3x3dwconv_3', 'stage3/block2/1x1conv_5', 'stage3/block2/bn_1x1conv_5', 'lambda_4', 'activation_11', 'stage3/block2/concat', 'stage3/block2/channel_shuffle', 'lambda_7', 'stage3/block3/1x1conv_4', 'stage3/block3/bn_1x1conv_4', 'activation_12', 'stage3/block3/3x3dwconv_3', 'stage3/block3/bn_3x3dwconv_3', 'stage3/block3/1x1conv_5', 'stage3/block3/bn_1x1conv_5', 'lambda_6', 'activation_13', 'stage3/block3/concat', 'stage3/block3/channel_shuffle', 'stage4/block1/1x1conv_2', 'stage4/block1/bn_1x1conv_2', 'activation_15', 'stage4/block1/3x3dwconv_1', 'stage4/block1/3x3dwconv_2', 'stage4/block1/bn_3x3dwconv_1', 'stage4/block1/bn_3x3dwconv_2', 'stage4/block1/1x1conv_1', 'stage4/block1/1x1conv_3', 'stage4/block1/bn_1x1conv_1', 'stage4/block1/bn_1x1conv_3', 'activation_14', 'activation_16', 'stage4/block1/concat', 'stage4/block1/channel_shuffle', 'lambda_9', 'stage4/block2/1x1conv_4', 'stage4/block2/bn_1x1conv_4', 'activation_17', 'stage4/block2/3x3dwconv_3', 'stage4/block2/bn_3x3dwconv_3', 'stage4/block2/1x1conv_5', 'stage4/block2/bn_1x1conv_5', 'lambda_8', 'activation_18', 'stage4/block2/concat', 'stage4/block2/channel_shuffle', 'conv5', 'global_average_pool', 'fc', 'activation_19']

# %%
import tensorflow as tf
import time
from keras import optimizers
opt = optimizers.SGD(lr=1e-2, momentum=0.9,decay=0.0008)
#opt = Adam(lr=INIT_LR,decay=INIT_LR / EPOCHS)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])  #CrossEntropyLoss  'categorical_crossentropy'
from keras.callbacks import ReduceLROnPlateau
lr_reducer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3
60
# 1123/1123 [==============================] - 93s 83ms/step - loss: 0.0226 - acc: 0.9931 - val_loss: 0.0309 - val_acc: 0.9957
# Epoch 51/60
# 1123/1123 [==============================] - 92s 82ms/step - loss: 0.0239 - acc: 0.9934 - val_loss: 0.0304 - val_acc: 0.9967
# Epoch 52/60
# 1123/1123 [==============================] - 91s 81ms/step - loss: 0.0266 - acc: 0.9918 - val_loss: 0.0232 - val_acc: 0.9953
# Epoch 53/60
# 1123/1123 [==============================] - 93s 83ms/step - loss: 0.0283 - acc: 0.9907 - val_loss: 0.0194 - val_acc: 0.9970
# Epoch 54/60
# 1123/1123 [==============================] - 92s 82ms/step - loss: 0.0255 - acc: 0.9925 - val_loss: 0.0299 - val_acc: 0.9947
# Epoch 55/60
# 1123/1123 [==============================] - 91s 81ms/step - loss: 0.0244 - acc: 0.9921 - val_loss: 0.0277 - val_acc: 0.9967
# Epoch 56/60
# 1123/1123 [==============================] - 109s 97ms/step - loss: 0.0223 - acc: 0.9932 - val_loss: 0.0252 - val_acc: 0.9963
# Epoch 57/60
# 1123/1123 [==============================] - 118s 105ms/step - loss: 0.0264 - acc: 0.9908 - val_loss: 0.0230 - val_acc: 0.9973
# Epoch 58/60
# 1123/1123 [==============================] - 92s 82ms/step - loss: 0.0298 - acc: 0.9909 - val_loss: 0.0262 - val_acc: 0.9970
# Epoch 59/60
# 1123/1123 [==============================] - 94s 84ms/step - loss: 0.0233 - acc: 0.9939 - val_loss: 0.0306 - val_acc: 0.9957
# Epoch 60/60
# 1123/1123 [==============================] - 92s 82ms/step - loss: 0.0239 - acc: 0.9933 - val_loss: 0.0286 - val_acc: 0.9960

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix,f1_score, precision_score, recall_score

Y_preds = model.predict(x_test)

Y_preds = np.argmax(Y_preds, axis=1)
Y_true = np.argmax(y_test, axis=1)

acc = accuracy_score(np.round(Y_preds),Y_true)*100
cm = confusion_matrix(Y_true, np.round(Y_preds))
precision=precision_score(np.round(Y_preds),Y_true,average='weighted')*100
recall=recall_score(np.round(Y_preds),Y_true,average='weighted')*100
#tn, fp, fn, tp = cm.ravel()

print('CONFUSION MATRIX ------------------')
print(cm)

print('\n============TEST METRICS=============')
#precision = tp/(tp+fp)*100
#recall = tp/(tp+fn)*100
print('Accuracy: {}%'.format(acc))
print('Precision: {}%'.format(precision))
print('Recall: {}%'.format(recall))
print('F1-score: {}'.format(2*precision*recall/(precision+recall)))

print('\nTRAIN METRIC ----------------------')
print('Train acc: {}'.format(np.round((history.history['acc'][-1])*100, 2)))
# Out:
# CONFUSION MATRIX ------------------
# [[509   0   0   0   0   0]
#  [  0 701   2   0   0   0]
#  [  1   0 609   0   0   0]
#  [  0   1   2 384   0   0]
#  [  0   4   1   0 289   0]
#  [  0   0   0   1   0 493]]
#
# ============TEST METRICS=============
# Accuracy: 99.5995995995996%
# Precision: 99.60251818329607%
# Recall: 99.5995995995996%
# F1-score: 99.6010588700672
#
# TRAIN METRIC ----------------------
# Train acc: 99.33

# %%
import numpy as np
from sklearn.metrics import classification_report,confusion_matrix
import itertools

Y_pred = model.predict(x_test)
y_pred = np.argmax(Y_pred, axis=1)
target_names = [ 'Commom rust','Bipolaris maydis','Curvularia lunata(wakker) boed spot','Northern leaf blight','Own spot','Sheath blight']
print(classification_report(np.argmax(y_test,axis=1), y_pred,target_names=target_names))
# Out:
#                                      precision    recall  f1-score   support
#
#                         Commom rust       1.00      1.00      1.00       509
#                    Bipolaris maydis       0.99      1.00      1.00       703
# Curvularia lunata(wakker) boed spot       0.99      1.00      1.00       610
#                Northern leaf blight       1.00      0.99      0.99       387
#                            Own spot       1.00      0.98      0.99       294
#                       Sheath blight       1.00      1.00      1.00       494
#
#                            accuracy                           1.00      2997
#                           macro avg       1.00      0.99      1.00      2997
#                        weighted avg       1.00      1.00      1.00      2997

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 2997/2997 [==============================] - 6s 2ms/step
# Test Accuracy: 99.5995995995996

# %%
test_loss,test_acc=model.evaluate(x_test,y_test)
print
9836339345224662, 0.9835226007570697, 0.9856379425517702, 0.982854598071787, 0.9864172790024494, 0.9870852816744601, 0.9877532843464707, 0.9846359385437542, 0.9878646181251391, 0.9858606101091071, 0.9890892896904921, 0.9880872856824761, 0.9888666221331552, 0.9876419505678022, 0.9875306167891338, 0.9887552883544868, 0.9890917186108638, 0.9893095768374165, 0.9903161175422974, 0.9917594654655669, 0.9916518254674977, 0.9915367483296214, 0.9922066354932086, 0.9922066354932086, 0.9908706301491873, 0.9916499665998664, 0.9924293030505456, 0.9930973057225563, 0.9934313070585615, 0.9917613003785348, 0.9906479625918504, 0.992540636829214, 0.9920953017145402, 0.9932086395012246, 0.9908706301359153, 0.9908706301491873, 0.9938766421732353, 0.9933199732798931]

# %%
print(history.history['loss'])
# Out:
# [1.165237330668383, 0.6563336316739178, 0.45574721232955795, 0.34426945608347304, 0.2654523325744337, 0.22440722246495276, 0.18949409627399805, 0.16627020051981153, 0.14557412454831048, 0.117105245376406, 0.1157958440170413, 0.10184346659774568, 0.10216363979839668, 0.09008364256932702, 0.08406157521772578, 0.07511253234793676, 0.07295395367195283, 0.0737142123676902, 0.06481239186114904, 0.06390129313201784, 0.05786356944291279, 0.052361847823272654, 0.05169593334370949, 0.04938469179925652, 0.04498620854461625, 0.0495999973862147, 0.041252693630930905, 0.04159353631779548, 0.039842182683617264, 0.04548737268580452, 0.03839952003528547, 0.04354199773873815, 0.03905340032418334, 0.03641058144750272, 0.036293255071148674, 0.03681633682785491, 0.038543089224645714, 0.03419542476259994, 0.03359650893233189, 0.03620034451048716, 0.029227665181705102, 0.028892775983356492, 0.02717031269612311, 0.028710521720678422, 0.026016923144125695, 0.02643934777248877, 0.029149409081845604, 0.024926842002247183, 0.02575969174480432, 0.022570740497447155, 0.02394209395320846, 0.026594122235509624, 0.02830513856060999, 0.025479551146308732, 0.02441368541248793, 0.022313864247489937, 0.026343830806167597, 0.029772765598817395, 0.023286093770475233, 0.023936967699154345]

# %%
pred = model.predict(x_test,verbose=1)
y_pred = np.argmax(pred, axis = 1)
y_pred
# Out:
# 2997/2997 [==============================] - 6s 2ms/step
# array([0, 5, 1, ..., 0, 0, 1], dtype=int64)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
        

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
cnf_matrix = (confusion_matrix(np.argmax(y_test,axis=1), y_pred))
np.set_printoptions(precision=2)
plt.figure(figsize=(7,7))
plot_confusion_matrix(cnf_matrix, classes=target_names,
                      title='Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[509   0   0   0   0   0]
#  [  0 701   2   0   0   0]
#  [  1   0 609   0   0   0]
#  [  0   1   2 384   0   0]
#  [  0   4   1   0 289   0]
#  [  0   0   0   1   0 493]]

# %%
import tensorflow as tf
import tensorflow.keras.backend as K

def get_flops(model):
    run_meta = tf.RunMetadata()
    opts = tf.profiler.ProfileOptionBuilder.float_operation()

    flops = tf.profiler.profile(graph=K.get_session().graph,
                                run_meta=run_meta, cmd='op', options=opts)
 
    return flops.total_float_ops

if __name__ == "__main__":
    x = K.random_normal(shape=(1, 1, 100, 256))
    model = ShuffleNet_V2(x.shape)
    print('FLOPs of tensorflow 1.12.0:', get_flops(model))
# Out:
# WARNING:tensorflow:From D:\anaconda\lib\site-packages\tensorflow\python\profiler\internal\flops_registry.py:142: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# FLOPs of tensorflow 1.12.0: 7112563
